# %% [markdown]
# # Self Attention Prototype

# %%
# !pip install torch==2.3.0
# !pip install torchtext==0.18
# !pip install torchvision==0.18
# Out:
# Collecting torch==2.3.0
#   Downloading torch-2.3.0-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (4.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.0 (from torch==2.3.0)
#   Downloading triton-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.3.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.3.0) (1.3.0)
# Downloading torch-2.3.0-cp311-cp311-manylinux1_x86_64.whl (779.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 73.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 49.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.1 MB/s eta 0:00:00
# Downloading triton-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.3.0 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.3.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 torch-2.3.0 triton-2.3.0
# Collecting torchtext==0.18
#   Downloading torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18) (2.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (4.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.3.0->torchtext==0.18) (12.5.82)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->torchtext==0.18) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=2.3.0->torchtext==0.18) (1.3.0)
# Downloading torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.0 MB/s eta 0:00:00
# Installing collected packages: torchtext
# Successfully installed torchtext-0.18.0
# Collecting torchvision==0.18
#   Downloading torchvision-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.18) (2.0.2)
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.18) (2.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.18) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (4.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0->torchvision==0.18) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->torchvision==0.18) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.3.0->torchvision==0.18) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.3.0->torchvision==0.18) (1.3.0)
# Downloading torchvision-0.18.0-cp311-cp311-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 28.8 MB/s eta 0:00:00
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# Successfully installed torchvision-0.18.0

# %%
# install check
import torch, torchtext

print("torch:", torch.__version__)
print("torchtext:", torchtext.__version__)
# Out:
# torch: 2.3.0+cu121
# torchtext: 0.18.0+cpu

# %%
# Google Drive Load
from google.colab import drive
drive.mount('/content/drive' )

import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/SKALA/GAI2.LLM')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### sonnets 코퍼스의 vocabulary 만들기

# %%
import torch
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

# Read the text file
with open('sonnets.txt', 'r') as file:
    text = file.read()

# Tokenize the text  (using simple tokenizer)
tokenizer = get_tokenizer('basic_english')
tokens = tokenizer(text)     # 전체 텍스트를 토큰 리스트로 변환
unique_tokens = set(tokens)  # 토큰 리스트에서 중복 제거

# %% [markdown]
# ### unique_tokens 집합을 이용해 단어 → 숫자(stoi) / 숫자 → 단어(itos) 매핑 만들기

# %%
stoi = { s:i for i,s in enumerate(unique_tokens)}
itos = { i:s for i,s in enumerate(unique_tokens)}
print(stoi)
print(itos)

vocab_size = len(unique_tokens)
print(vocab_size)
# Out:
# {'seasons': 0, 'persuade': 1, 'monsters': 2, 'coming': 3, 'place': 4, 'compounds': 5, 'without': 6, 'travel': 7, 'dregs': 8, 'maid': 9, 'user': 10, 'everywhere': 11, 'self-love': 12, 'make': 13, 'breathers': 14, 'of': 15, 'spot': 16, 'prouder': 17, 'reviewest': 18, 'dispense': 19, 'shines': 20, 'dreaming': 21, 'sorry': 22, 'beseem': 23, 'leisure': 24, 'inheritors': 25, 'frost': 26, 'skill': 27, 'better': 28, 'climbed': 29, 'ornaments': 30, 'victors': 31, 'pleased': 32, 'fulness': 33, 'can': 34, 'uphold': 35, 'mud': 36, 'ring': 37, 'painting': 38, 'ink': 39, 'bent': 40, 'fruit': 41, 'lovely': 42, 'damasked': 43, 'strange': 44, 'shore': 45, 'essays': 46, 'frailties': 47, 'vouchsafe': 48, 'chiding': 49, 'perusal': 50, 'seek': 51, 'survive': 52, 'huge': 53, 'shamed': 54, 'hid': 55, 'thanks': 56, 'blunting': 57, 'ruined': 58, 'incapable': 59, 'thence': 60, 'friends': 61, 'knows': 62, 'bears': 63, 'yea': 64, 'lodged': 65, 'other': 66, 'defeat': 67, 'decree': 68, 'complexion': 69, 'inward': 70, 'souls': 71, 'drops': 72, '(': 73, 'am': 74, 'shadow': 75, 'depends': 76, 'harmful': 77, 'spacious': 78, 'believed': 79, 'tongues': 80, 'determination': 81, 'end': 82, 'worship': 83, 'return': 84, 'food': 85, 'delight': 86, 'banks': 87, 'shown': 88, 'kingdoms': 89, 'strained': 90, 'extant': 91, 'records': 92, 'laws': 93, 'featureless': 94, 'strains': 95, 'their': 96, 'ushers': 97, 'concord': 98, 'renew': 99, 'rents': 100, 'shoot': 101, 'tend': 102, 'famished': 103, 'us': 104, 'survey': 105, 'quite': 106, 'tune': 107, 'seat': 108, 'imaginary': 109, 'partly': 110, 'wisdom': 111, 'foe': 112, 'may': 113, 'rocks': 114, 'fashion': 115, 'goes': 116, 'fester': 117, 'sees': 118, 'love': 119, 'blame': 120, 'twilight': 121, 'summers': 122, 'heard': 123, 'mark': 124, 'eye': 125, 'play': 126, 'compeers': 127, 'flow': 128, 'bad': 129, 'neglect': 130, 'tyranny': 131, 'adonis': 132, 'base': 133, 'vaunt': 134, 'sum': 135, 'bristly': 136, 'ertake': 137, 'widowed': 138, 'tender': 139, 'strumpeted': 140, 'power': 141, 'finds': 142, 'attainted': 143, 'need': 144, 'beyond': 145, 'weep': 146, 'dyed': 147, 'stamped': 148, 'deserved': 149, 'whole': 150, 'fore': 151, 'measured': 152, 'salve': 153, 'heat': 154, 'old': 155, 'endure': 156, 'decrepit': 157, 'all-eating': 158, 'perfumed': 159, 'feasts': 160, 'worse': 161, 'full': 162, 'plain': 163, 'drunk': 164, 'birth': 165, 'losing': 166, 'white': 167, 'hairs': 168, 'bends': 169, 'whether': 170, 'vow': 171, 'ignorance': 172, 'building': 173, 'created': 174, 'passed': 175, 'children': 176, 'kiss': 177, 'though': 178, 'coral': 179, 'seemed': 180, 'poisoned': 181, 'works': 182, 'dignified': 183, 'appetite': 184, 'cherubins': 185, 'new': 186, 'beautiful': 187, 'coloured': 188, 'till': 189, 'follows': 190, 'eclipse': 191, 'trees': 192, 'evident': 193, 'swears': 194, 'only': 195, 'weed': 196, 'images': 197, 'an': 198, 'wherein': 199, 'dispraise': 200, 'spoils': 201, 'pitied': 202, 'account': 203, 'precious': 204, 'crawls': 205, 'wherewith': 206, 'engraft': 207, 'repair': 208, 'virtuous': 209, 'suffered': 210, 'give': 211, 'wantonness': 212, 'spoil': 213, 'rotten': 214, 'mended': 215, 'seals': 216, 'made': 217, 'wires': 218, 'wide': 219, 'worths': 220, 'invent': 221, 'sides': 222, 'contracted': 223, 'entitled': 224, 'why': 225, 'husband': 226, 'clearer': 227, 'tie': 228, 'stopped': 229, 'each': 230, 'enlarged': 231, 'frown': 232, 'soundless': 233, 'olives': 234, 'exchanged': 235, 'monuments': 236, 'polished': 237, 'heretic': 238, 'removed': 239, 'canopy': 240, 'expiate': 241, 'freedom': 242, 'tan': 243, 'perfect': 244, 'apple': 245, 'rud': 246, 'untainted': 247, 'urge': 248, 'usury': 249, 'death-bed': 250, 'female': 251, 'dumb': 252, 'something': 253, 'history': 254, 'busy': 255, 'divert': 256, 'slavery': 257, 'little': 258, 'bareness': 259, 'advance': 260, 'vainly': 261, 'habit': 262, 'prone': 263, 'vowing': 264, 'swift-footed': 265, 'manners': 266, 'defy': 267, 'story': 268, 'beshrew': 269, 'husbandry': 270, 'happier': 271, 'a ...
# {0: 'seasons', 1: 'persuade', 2: 'monsters', 3: 'coming', 4: 'place', 5: 'compounds', 6: 'without', 7: 'travel', 8: 'dregs', 9: 'maid', 10: 'user', 11: 'everywhere', 12: 'self-love', 13: 'make', 14: 'breathers', 15: 'of', 16: 'spot', 17: 'prouder', 18: 'reviewest', 19: 'dispense', 20: 'shines', 21: 'dreaming', 22: 'sorry', 23: 'beseem', 24: 'leisure', 25: 'inheritors', 26: 'frost', 27: 'skill', 28: 'better', 29: 'climbed', 30: 'ornaments', 31: 'victors', 32: 'pleased', 33: 'fulness', 34: 'can', 35: 'uphold', 36: 'mud', 37: 'ring', 38: 'painting', 39: 'ink', 40: 'bent', 41: 'fruit', 42: 'lovely', 43: 'damasked', 44: 'strange', 45: 'shore', 46: 'essays', 47: 'frailties', 48: 'vouchsafe', 49: 'chiding', 50: 'perusal', 51: 'seek', 52: 'survive', 53: 'huge', 54: 'shamed', 55: 'hid', 56: 'thanks', 57: 'blunting', 58: 'ruined', 59: 'incapable', 60: 'thence', 61: 'friends', 62: 'knows', 63: 'bears', 64: 'yea', 65: 'lodged', 66: 'other', 67: 'defeat', 68: 'decree', 69: 'complexion', 70: 'inward', 71: 'souls', 72: 'drops', 73: '(', 74: 'am', 75: 'shadow', 76: 'depends', 77: 'harmful', 78: 'spacious', 79: 'believed', 80: 'tongues', 81: 'determination', 82: 'end', 83: 'worship', 84: 'return', 85: 'food', 86: 'delight', 87: 'banks', 88: 'shown', 89: 'kingdoms', 90: 'strained', 91: 'extant', 92: 'records', 93: 'laws', 94: 'featureless', 95: 'strains', 96: 'their', 97: 'ushers', 98: 'concord', 99: 'renew', 100: 'rents', 101: 'shoot', 102: 'tend', 103: 'famished', 104: 'us', 105: 'survey', 106: 'quite', 107: 'tune', 108: 'seat', 109: 'imaginary', 110: 'partly', 111: 'wisdom', 112: 'foe', 113: 'may', 114: 'rocks', 115: 'fashion', 116: 'goes', 117: 'fester', 118: 'sees', 119: 'love', 120: 'blame', 121: 'twilight', 122: 'summers', 123: 'heard', 124: 'mark', 125: 'eye', 126: 'play', 127: 'compeers', 128: 'flow', 129: 'bad', 130: 'neglect', 131: 'tyranny', 132: 'adonis', 133: 'base', 134: 'vaunt', 135: 'sum', 136: 'bristly', 137: 'ertake', 138: 'widowed', 139: 'tender', 140: 'strumpeted', 141: 'power', 142: 'finds', 143: 'attainted', 144: 'need', 145: 'beyond', 146: 'weep', 147: 'dyed', 148: 'stamped', 149: 'deserved', 150: 'whole', 151: 'fore', 152: 'measured', 153: 'salve', 154: 'heat', 155: 'old', 156: 'endure', 157: 'decrepit', 158: 'all-eating', 159: 'perfumed', 160: 'feasts', 161: 'worse', 162: 'full', 163: 'plain', 164: 'drunk', 165: 'birth', 166: 'losing', 167: 'white', 168: 'hairs', 169: 'bends', 170: 'whether', 171: 'vow', 172: 'ignorance', 173: 'building', 174: 'created', 175: 'passed', 176: 'children', 177: 'kiss', 178: 'though', 179: 'coral', 180: 'seemed', 181: 'poisoned', 182: 'works', 183: 'dignified', 184: 'appetite', 185: 'cherubins', 186: 'new', 187: 'beautiful', 188: 'coloured', 189: 'till', 190: 'follows', 191: 'eclipse', 192: 'trees', 193: 'evident', 194: 'swears', 195: 'only', 196: 'weed', 197: 'images', 198: 'an', 199: 'wherein', 200: 'dispraise', 201: 'spoils', 202: 'pitied', 203: 'account', 204: 'precious', 205: 'crawls', 206: 'wherewith', 207: 'engraft', 208: 'repair', 209: 'virtuous', 210: 'suffered', 211: 'give', 212: 'wantonness', 213: 'spoil', 214: 'rotten', 215: 'mended', 216: 'seals', 217: 'made', 218: 'wires', 219: 'wide', 220: 'worths', 221: 'invent', 222: 'sides', 223: 'contracted', 224: 'entitled', 225: 'why', 226: 'husband', 227: 'clearer', 228: 'tie', 229: 'stopped', 230: 'each', 231: 'enlarged', 232: 'frown', 233: 'soundless', 234: 'olives', 235: 'exchanged', 236: 'monuments', 237: 'polished', 238: 'heretic', 239: 'removed', 240: 'canopy', 241: 'expiate', 242: 'freedom', 243: 'tan', 244: 'perfect', 245: 'apple', 246: 'rud', 247: 'untainted', 248: 'urge', 249: 'usury', 250: 'death-bed', 251: 'female', 252: 'dumb', 253: 'something', 254: 'history', 255: 'busy', 256: 'divert', 257: 'slavery', 258: 'little', 259: 'bareness', 260: 'advance', 261: 'vainly', 262: 'habit', 263: 'prone', 264: 'vowing', 265: 'swift-footed', 266: 'manners', 267: 'defy', 268: 'story', 269: 'beshrew', 270: 'husbandry', 271: 'happier', 27 ...
# 3129

# %% [markdown]
# ### 문장을 정수 인덱스로 바꾸고 → 임베딩 층을 거쳐 벡터 표현으로 변환

# %%
sentence = "i love you"
indices = [stoi[word] for word in sentence.split()]  # 띄어쓰기 기준으로 분리하고 숫자 인덱스 변환
print(indices)

import torch.nn as nn

# 입력: 단어 인덱스 (정수)
# 출력: 각 단어의 임베딩 벡터

embedding_dim = 20
embedding = nn.Embedding(vocab_size, embedding_dim)

embedded_sentence = embedding(torch.tensor(indices))
print(embedded_sentence)
# Out:
# [2485, 119, 2189]
# tensor([[-0.7202, -1.4790,  0.0096,  0.2148, -0.6859, -0.0440, -0.4941,  0.4224,
#           0.3153,  0.7374,  2.0883,  0.8282,  0.3581, -0.1634,  0.2305, -0.9165,
#           1.2477,  0.2477,  1.1511, -0.0563],
#         [ 0.3011, -0.1361, -0.6116,  0.3114, -0.1752, -0.8227,  1.4952,  1.3835,
#          -1.6882,  0.8879, -0.6785, -1.5725, -0.1478, -0.3587, -0.9277, -0.7567,
#           1.2114,  1.3855, -1.1729,  0.2567],
#         [ 1.0861,  0.5161,  2.2962,  0.6927, -1.6665,  0.5236,  1.0746,  1.2003,
#           0.7955,  0.0320,  0.4892, -2.2618,  1.1577, -0.1324,  0.9927,  0.0076,
#          -1.4505,  0.1624, -0.7121,  0.9599]], grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# ### Self Attention

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SelfAttention(nn.Module):
    def __init__(self, embed_dim, atten_dim):
        super().__init__()
        self.query = nn.Linear(embed_dim, atten_dim, bias=False)
        self.key = nn.Linear(embed_dim, atten_dim, bias=False)
        self.value = nn.Linear(embed_dim, atten_dim, bias=False)

    def forward(self, x):
        query = self.query(x)
        key = self.key(x)
        value = self.value(x)

        scores = torch.matmul(query, key.transpose(-2, -1))
        scores = scores / key.size(-1)**0.5

        attention_weights = F.softmax(scores, dim=-1)
        weighted_values = torch.matmul(attention_weights, value)

        return weighted_values

# %%
# Create an instance of SelfAttention
# 벡터들을 서로 비교해서 관계(유사도)를 계산하고 새로운 표현(예: 5차원)으로 변환
# 출력은 각 단어가 문장 내 다른 단어와의 관계를 반영한 컨텍스트 벡터

atten_dim = 5
self_attention = SelfAttention(embedding_dim, atten_dim)

output = self_attention(embedded_sentence)
print(output)
# Out:
# tensor([[ 0.3025, -0.3198,  0.1056,  0.0735, -0.0726],
#         [ 0.0955, -0.1943,  0.1120,  0.0607,  0.0151],
#         [-0.1662, -0.0401,  0.1317,  0.0092,  0.1101],
#         [-0.0298, -0.1407,  0.1216, -0.0071,  0.0339]], grad_fn=<MmBackward0>)
