# %%
#### 다음 실습 코드는 학습 목적으로만 사용 바랍니다. 문의 : audit@korea.ac.kr 임성열 Ph.D.

# !pip install mlflow scikit-learn numpy pandas

from pathlib import Path
Path("mlruns/.trash").mkdir(parents=True, exist_ok=True)  # 루트 + .trash 동시 생성
# Out:
# Collecting mlflow
#   Downloading mlflow-3.4.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.3.1)
# Collecting mlflow-skinny==3.4.0 (from mlflow)
#   Downloading mlflow_skinny-3.4.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.4.0 (from mlflow)
#   Downloading mlflow_tracing-3.4.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow) (1.16.4)
# Collecting cryptography<46,>=43.0.0 (from mlflow)
#   Downloading cryptography-45.0.7-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting fastmcp<3,>=2.0.0 (from mlflow)
#   Downloading fastmcp-2.12.4-py3-none-any.whl.metadata (19 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scipy<2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow) (1.11.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow) (2.0.43)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.4.0->mlflow)
#   Downloading databricks_sdk-0.67.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: fastapi<1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (0.117.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (8.7.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.4.0->mlflow)
#   Downloading opentelemetry_api-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.4.0->mlflow)
#   Downloading opentelemetry_proto-1.37.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.4.0->mlflow)
#   Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from mlflow-skinny==3.4.0->mlflow) (5.29.5)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (2.11.9)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (1.1.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from mlflow-skinny==3.4.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (2.32.5)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.4.0->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from mlflow-skinny==3.4.0->mlflow) (4.14.1)
# Requirement already satisfied: uvicorn<1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow) (0.35.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: Mako in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cryptography<46,>=43.0.0->mlflow) (2.0.0)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow)
#   Downloading google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow) (0.47.3)
# Collecting authlib>=1.5.2 (from fastmcp<3,>=2.0.0->mlflow)
#   Downloading authlib-1.6.5-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting cyclopts>=3.0.0 (from fastmcp<3,>=2.0.0->mlflow)
#   Downloading cyclopts-3.24.0-py3-none-any.whl.metadata (11 kB)
# Collecting exceptiongroup>=1.2.2 (from fastmcp<3,>=2.0.0->mlflow)
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: httpx>=0.28.1 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from fastmcp<3,>=2.0.0->mlflow) (0.28.1)
# Collecting mcp<2.0.0,>=1.12.4 (from fastmcp<3,>=2.0.0->mlflow)
#   Downloading mcp-1.15.0-py3-none-any.whl.metadata (80 kB)
# Collecting openapi-core>=0.19.5 (from fastmcp<3,>=2.0.0->mlflow)
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting openapi-pydantic>=0.5.1 (from fastmcp<3,>=2.0.0->mlflow)
#   Downloading openapi_pydantic-0.5.1-py3-none-any.whl.metadata (10 kB)
# Collecting pyperclip>=1.9.0 (from fastmcp<3,>=2.0.0->mlflow)
#   Downloading pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: rich>=13.9.4 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from fastmcp<3,>=2.0.0->mlflow) (14.1.0)
# Requirement already satisfied: blinker>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from Flask<4->mlflow) (1.9.0)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (5.0.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (4.9.1)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: zipp>=3.20 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4->mlflow) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: anyio>=4.5 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (4.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.0.20)
# Collecting sse-starlette>=1.6.1 (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow)
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Collecting opentelemetry-semantic-conventions==0.58b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from uvicorn<1->mlflow-skinny==3.4.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow) (2.22)
# Requirement already satisfied: attrs>=23.1.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (25.3.0)
# Collecting docstring-parser>=0.15 (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting rich-rst<2.0.0,>=1.3.1 (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow)
#   Downloading rich_rst-1.3.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting docutils (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow)
#   Downloading docutils-0.22.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: httpcore==1.* in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.26.0)
# Collecting isodate (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow)
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: more-itertools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (10.7.0)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow)
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow)
#   Downloading openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow)
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: rfc3339-validator in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.1.4)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow)
#   Downloading lazy_object_proxy-1.12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: email-validator>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/ichangmin/Library/Python/3.11/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (0.1.2)
# Downloading mlflow-3.4.0-py3-none-any.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 11.3 MB/s  0:00:02 eta 0:00:01
# Downloading mlflow_skinny-3.4.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.2 MB/s  0:00:00
# Downloading mlflow_tracing-3.4.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.0 MB/s  0:00:00
# Downloading cryptography-45.0.7-cp311-abi3-macosx_10_9_universal2.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 11.5 MB/s  0:00:00 eta 0:00:01
# Downloading databricks_sdk-0.67.0-py3-none-any.whl (718 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.4/718.4 kB 10.4 MB/s  0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastmcp-2.12.4-py3-none-any.whl (329 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading mcp-1.15.0-py3-none-any.whl (166 kB)
# Downloading opentelemetry_api-1.37.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.37.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl (131 kB)
# Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl (207 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading authlib-1.6.5-py2.py3-none-any.whl (243 kB)
# Downloading cyclopts-3.24.0-py3-none-any.whl (86 kB)
# Downloading rich_rst-1.3.1-py3-none-any.whl (11 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Downloading lazy_object_proxy-1.12.0-cp311-cp311-macosx_11_0_arm64.whl (26 kB)
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
# Downloading openapi_pydantic-0.5.1-py3-none-any.whl (96 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Downloading docutils-0.22.2-py3-none-any.whl (632 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 10.4 MB/s  0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: pyperclip, parse, werkzeug, sqlparse, pyasn1-modules, pathable, opentelemetry-proto, lazy-object-proxy, itsdangerous, isodate, gunicorn, graphql-core, exceptiongroup, docutils, docstring-parser, sse-starlette, opentelemetry-api, jsonschema-path, graphql-relay, google-auth, Flask, docker, cryptography, rich-rst, opentelemetry-semantic-conventions, openapi-pydantic, graphene, databricks-sdk, authlib, opentelemetry-sdk, openapi-schema-validator, mcp, cyclopts, openapi-spec-validator, mlflow-tracing, mlflow-skinny, openapi-core, fastmcp, mlflow
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: cryptography╺━━━━━━━━━━━━━━━━━━━━ 19/39 [google-auth]y-proto]
#     Found existing installation: cryptography 46.0.1━━━━━━━━━━ 19/39 [google-auth]
#     Uninstalling cryptography-46.0.1:━━━━━━━━━━━━━━━━━━━━ 19/39 [google-auth]
#       Successfully uninstalled cryptography-46.0.1━━━━━━━━━━━━ 19/39 [google-auth]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39/39 [mlflow]38/39 [mlflow]skinny]]c-conventions]
# Successfully installed Flask-3.1.2 authlib-1.6.5 cryptography-45.0.7 cyclopts-3.24.0 databricks-sdk-0.67.0 docker-7.1.0 docstring-parser-0.17.0 docutils-0.22.2 exceptiongroup-1.3.0 fastmcp-2.12.4 google-auth-2.41.1 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 isodate-0.7.2 itsdangerous-2.2.0 jsonschema-path-0.3.4 lazy-object-proxy-1.12.0 mcp-1.15.0 mlflow-3.4.0 mlflow-skinny-3.4.0 mlflow-tracing-3.4.0 openapi-core-0.19.5 openapi-pydantic-0.5.1 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 opentelemetry-api-1.37.0 opentelemetry-proto-1.37.0 opentelemetry-sdk-1.37.0 opentelemetry-semantic-conventions-0.58b0 parse-1.20.2 pathable-0.4.4 pyasn1-modules-0.4.2 pyperclip-1.11.0 rich-rst-1.3.1 sqlparse-0.5.3 sse-starlette-3.0.2 werkzeug-3.1.1

# %%
import os, getpass
from datetime import datetime
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from mlflow.models import infer_signature
import numpy as np

if mlflow.active_run() is not None: # MLflow 사용 시, 현재 파이썬 프로세스 (현재 쓰레드)에서 실행 중인 run이 있으면 종료, mlflow.start_run()을 여러 번 호출하면 중첩 run 에러
    mlflow.end_run()
    
mlflow.set_experiment("diabetes_experiment1")  # experiment_id가 아님!

# 사용자/리비전 정보 태깅
user = getpass.getuser()
run_name = f"{user}-rf-{datetime.now():%m%d_%H%M}"
    
# 일반적으로는 학습 코드 내부에 MLflow 로깅을 심어(autolog 또는 수동 log) 각 사용자가 자신의 실험을 남기는 방식으로 사용
# 보통은 중앙 Tracking Server(MLflow 서버) 를 띄우고, 각 사용자가 자신의 개발 환경(노트북/서버/CI)에서 HTTP로 로그를 보내는 구조 사용
    
# Experiment name으로 설정해야 함
mlflow.autolog()  # 자동 로깅 활성화

# 데이터 준비
X, y = load_diabetes(return_X_y=True) # load_diabetes()는 scikit-learn에서 제공하는 내장 예제 데이터셋 로더 함수
X_train, X_test, y_train, y_test = train_test_split(X, y)

# 실험 시작
with mlflow.start_run() as run:
    model = RandomForestRegressor(n_estimators=100)
    model.fit(X_train, y_train)

    score = model.score(X_test, y_test)
    
    # 파라미터, 메트릭 기록
    mlflow.log_param("n_estimators", 100)
    mlflow.log_metric("r2_score", score)

    # 입력 예시 추가 (테스트 데이터의 첫 번째 샘플)
    input_example = X_test[:1]

    # signature 자동 생성
    signature = infer_signature(X_test, model.predict(X_test))
    # signature는 MLflow 모델 저장 시, 입력과 출력 데이터의 스키마(형식)를 명시하는 객체이며 이를 통해 MLflow는 모델을 저장할 때, 해당 모델이 "어떤 입력을 받고 어떤 출력을 낼지"를 명시적으로 기록

    # 모델 저장 (input_example과 signature 추가)
    mlflow.sklearn.log_model(
        sk_model=model,
        name="model",
        input_example=input_example,
        signature=signature # 
    )

print("MLflow run completed with model, input_example, and signature.")
# Out:
# 2025/10/02 22:47:12 INFO mlflow.tracking.fluent: Experiment with name 'diabetes_experiment1' does not exist. Creating a new experiment.
# 2025/10/02 22:47:13 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# MLflow run completed with model, input_example, and signature.

# %%
import mlflow
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

if mlflow.active_run() is not None: # MLflow 사용 시, 현재 실행 중인 run이 있으면 종료, mlflow.start_run()을 여러 번 호출하면 중첩 run 에러
    mlflow.end_run()

# Experiment name으로 설정해야 함
mlflow.set_experiment("diabetes_experiment2")  # experiment_id가 아님!

# 일반적으로는 학습 코드 내부에 MLflow 로깅을 심어(autolog 또는 수동 log) 각 사용자가 자신의 실험을 남기는 방식으로 사용
# 보통은 중앙 Tracking Server(MLflow 서버) 를 띄우고, 각 사용자가 자신의 개발 환경(노트북/서버/CI)에서 HTTP로 로그를 보내는 구조 사용

# 사용자/리비전 정보 태깅
user = getpass.getuser()
run_name = f"{user}-rf-{datetime.now():%m%d_%H%M}"

mlflow.autolog()  # 자동 로깅 활성화

db = load_diabetes()

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Autologging은 mlflow.start_run() 안에서 안정적으로 동작
with mlflow.start_run():
    rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
    rf.fit(X_train, y_train)

    # 모델 예측 (autolog가 알아서 기록)
    predictions = rf.predict(X_test)
# Out:
# 2025/10/02 22:47:16 INFO mlflow.tracking.fluent: Experiment with name 'diabetes_experiment2' does not exist. Creating a new experiment.
# 2025/10/02 22:47:16 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.

# %%
# 참고로, 여러 모델러들이 작업 공유를 위해서는 mlflow server(서버)를 셋팅하여 사용합니다. (실험 로그 수집 및 모델 레포지토리 공유, 추적 용이)
# 서버 버전 적용도 기존 mlflow 설치만으로 충분하고, 확장 기능(DB/클라우드) 을 쓸 때만 드라이버를 추가 셋업하여 사용합니다.
'''mlflow server \
  --host 127.0.0.1 --port 5003 \
  --backend-store-uri "mysql+pymysql://manager:passwd@127.0.0.1:53301/sql_db" \
  --artifacts-destination file:///mnt/mlflow-artifacts \
  --serve-artifacts'''

# 본 과정에서는 여러 모델러들간 실험 로그 수집 및 모델 레포지토리 공유 등이 목적이 아니므로, 로컬에서 mlflow ui를 사용하여 테스트합니다.
# 참고로 본 과정에서는 AI서비스 서비스 목적에 맞게, "예측형 AI 모델 서빙 및 AIOps 구성" 능력에 초점을 두고 있습니다.

# mlflwo ui 사용을 위해 다음 코드를 실행합니다. (모델, 레포지토리는 로컬 실행 버전 조회)
# 학습을 실행시키는 코드 위치 밑에 mlruns 폴더가 생기며, mlflow ui도 현 위치에서 실행시켜야 합니다.
# mlflow ui --host 127.0.0.1 --port 5001 # mlflow ui를 실행, 5000번은 구글 예약 포트
# Out:
# 'mlflow server   --host 127.0.0.1 --port 5003   --backend-store-uri "mysql+pymysql://manager:passwd@127.0.0.1:53301/sql_db"   --artifacts-destination file:///mnt/mlflow-artifacts   --serve-artifacts'
